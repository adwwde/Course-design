# %%
import pandas as pd
import lightgbm as lgb
import numpy as np
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import KFold
# from lightgbm import LGBMClassifier
from lightgbm import LGBMRegressor
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm.notebook import tqdm
import gc

import warnings
warnings.simplefilter('ignore')

# %%
train = pd.read_csv('train_dataset.csv')
test = pd.read_csv('evaluation_public.csv')

train['isnull'] = train.iloc[:,1:].isnull().mean(axis = 1)
test['isnull'] = test.iloc[:,1:].isnull().mean(axis = 1)

data = pd.concat([train, test]).reset_index(drop=True)

data['time'] = pd.to_datetime(data['time'])
data['hour'] = data['time'].dt.hour
data['minute'] = data['time'].dt.minute
data['weekday'] = data['time'].dt.weekday
data['ts'] = data['hour']*60 + data['minute']

# %%
train = data.iloc[:140480].reset_index(drop = True)
test = data.iloc[140480:].reset_index(drop = True)

## 对比测试集每行样本的特征缺失比，选取特征缺失比率相识的
train = train[train['isnull']<0.15].reset_index(drop=True)

train['Label1_log'] = np.log1p(train['Label1'])
train['Label2_log'] = np.log1p(train['Label2'])


## 通过特征重要性、对抗验证、特征相关性，剔除了这7个特征，可能剔除错了也可能没剔除干净
# feas = [f for f in train.columns if f not in ['time', 'Label1', 'Label2','Label1_log','Label2_log', 
#                                               'B_QY_ORP','JS_TN',
#                                               'CS_SW','MCCS_NH4','N_HYC_JS_DO','MCCS_NO3','JS_SW',
#                                              ]]
# 'Label1_log','Label2_log'
feas1 = [f for f in train.columns if f not in ['time', 'Label1', 'Label2','N_HYC_NH4','Label1_log','Label2_log',
                                              'N_HYC_XD','N_HYC_MLSS','N_HYC_JS_DO','N_HYC_DO','N_CS_MQ_SSLL','N_QY_ORP',
                                                 'hour','weekday','isnull']]

feas2 = [f for f in train.columns if f not in ['time', 'Label1', 'Label2','B_HYC_NH4','Label1_log','Label2_log',
                                              'B_HYC_XD','B_HYC_MLSS','B_HYC_JS_DO','B_HYC_DO','B_CS_MQ_SSLL','B_QY_ORP',
                                              'hour','weekday','isnull']]
train = train.dropna(subset=['Label1', 'Label2']).reset_index(drop=True)




x_trainB = train[feas1]
x_trainN = train[feas2]
x_testB = test[feas1]
x_testN = test[feas2]



# 做点比率数值特征   进/出口的比率
def add_ratio_feats(df, type_='B'):
    df['JS_CS_NH3_ratio'] = df['JS_NH3'] / (df['CS_NH3'] + 1e-3)
    df['JS_CS_TN_ratio'] = df['JS_TN'] / (df['CS_TN'] + 1e-3)
    df['JS_CS_LL_ratio']  = df['JS_LL'] / (df['CS_LL'] + 1e-3)
    df['MCCS_NH4_NH3_ratio'] = df['MCCS_NH4'] / (df['CS_NH3'] + 1e-3)
    df['MCCS_NO3_NH3_ratio'] = df['MCCS_NO3'] / (df['CS_NH3'] + 1e-3)
    df['JS_CS_COD_ratio'] = df['JS_COD'] / (df['CS_COD'] + 1e-3)
    df['JS_CS_SW_ratio'] = df['JS_SW'] / (df['CS_SW'] + 1e-3)
    df['HYC_DO_ratio'] = df[f'{type_}_HYC_JS_DO'] / (df[f'{type_}_HYC_DO'] + 1e-3)
    df['CS_MQ_LL_ratio'] = df[f'{type_}_CS_MQ_SSLL'] / (df['CS_LL'] + 1e-3)
    
    return df
x_trainB = add_ratio_feats(x_trainB, type_='B')
x_trainN = add_ratio_feats(x_trainN, type_='N')
x_testB = add_ratio_feats(x_testB, type_='B')
x_testN = add_ratio_feats(x_testN, type_='N')

# %%
def lgb_model(clf, train_x, train_y, test_x):
    folds = 10
    seed = 2222
    kf = KFold(n_splits=folds, shuffle=True, random_state=seed)

    train = np.zeros(train_x.shape[0])
    test = np.zeros(test_x.shape[0])

    cv_scores = []
    test_pre = []
    Feass = pd.DataFrame()

    for i, (train_index, valid_index) in enumerate(kf.split(train_x, train_y)):
        print('************************************ {} ************************************'.format(str(i+1)))
        trn_x, trn_y, val_x, val_y = train_x.iloc[train_index], train_y[train_index], train_x.iloc[valid_index], train_y[valid_index]

        train_matrix = clf.Dataset(trn_x, label=trn_y)
        valid_matrix = clf.Dataset(val_x, label=val_y)
        fea = pd.DataFrame()

        params = {
            'learning_rate': 0.02,
            'boosting_type': 'gbdt',
            'objective': 'mse',
            'metric': 'mse',
            'verbose': -1,
            'seed': 2020,
            'n_jobs': -1,
            'max_depth':-1,
            'min_child_weight': 4,
            'num_leaves': 2 ** 4,
            'feature_fraction': 0.8,
            'bagging_fraction': 0.8,
            'bagging_freq': 4,
        }

        model = clf.train(params, train_matrix, num_boost_round=20000, valid_sets=[train_matrix, valid_matrix], 
                          categorical_feature =[] ,verbose_eval=1000,early_stopping_rounds=200)
        val_pred = model.predict(val_x, num_iteration=model.best_iteration)
        test_pred = model.predict(test_x, num_iteration=model.best_iteration)
        test_pre.append(test_pred)
        fea['feas'] = train_x.columns.tolist()
        fea['sorce'] = model.feature_importance()
        Feass = pd.concat([Feass,fea],axis = 0)
        print(list(sorted(zip(train_x.columns.tolist(), model.feature_importance()), key=lambda x: x[1], reverse=True))[:20])
            
            
        train[valid_index] = val_pred
        test = test_pred
        #标准差
        cv_scores.append(np.sqrt(mean_squared_error(np.expm1(val_y), np.expm1(val_pred))))
#         cv_scores.append(mean_squared_error(val_y, val_pred))
  
        print(cv_scores)
    test = sum(test_pre) / folds
    print("s_scotrainre_list:" , cv_scores)
    print("s_score_mean:" , np.mean(cv_scores))
    print("s_score_std:", np.std(cv_scores))

    return train, test, Feass, np.mean(cv_scores)

# %%
for idx, i in enumerate([[x_trainB, train['Label1_log'], x_testB], [x_trainN, train['Label2_log'], x_testN],]):
    locals()[f'lgb_train{idx}'], locals()[f'lgb_test{idx}'], \
    locals()[f'Feass{idx}'],     locals()[f'scores{idx}'] = lgb_model(lgb, i[0], i[1], i[2])
# Out:
# ************************************ 1 ************************************
# Training until validation scores don't improve for 200 rounds
# [1000]	training's l2: 0.00935668	valid_1's l2: 0.015895
# [2000]	training's l2: 0.0064533	valid_1's l2: 0.0143328
# [3000]	training's l2: 0.00499404	valid_1's l2: 0.0135379
# [4000]	training's l2: 0.00406647	valid_1's l2: 0.0131103
# [5000]	training's l2: 0.00341676	valid_1's l2: 0.0128115
# [6000]	training's l2: 0.0029235	valid_1's l2: 0.012601
# [7000]	training's l2: 0.00253126	valid_1's l2: 0.0124498
# [8000]	training's l2: 0.00221772	valid_1's l2: 0.012304
# [9000]	training's l2: 0.00195561	valid_1's l2: 0.0122112
# [10000]	training's l2: 0.00174002	valid_1's l2: 0.0121135
# [11000]	training's l2: 0.0015549	valid_1's l2: 0.0120804
# Early stopping, best iteration is:
# [10999]	training's l2: 0.00155507	valid_1's l2: 0.0120803
# [('ts', 9458), ('B_HYC_DO', 8824), ('MCCS_NH4', 8076), ('MCCS_NO3', 7919), ('B_HYC_MLSS', 7391), ('B_QY_ORP', 7321), ('JS_CS_SW_ratio', 7149), ('JS_LL', 6728), ('minute', 6626), ('JS_SW', 6615), ('B_CS_MQ_SSLL', 6461), ('B_HYC_JS_DO', 6364), ('B_HYC_XD', 6253), ('MCCS_NH4_NH3_ratio', 6150), ('HYC_DO_ratio', 5992), ('CS_SW', 5385), ('MCCS_NO3_NH3_ratio', 4951), ('CS_TN', 4456), ('CS_COD', 4413), ('JS_CS_LL_ratio', 4413)]
# [1411.8167258243056]
# ************************************ 2 ************************************
# Training until validation scores don't improve for 200 rounds
# [1000]	training's l2: 0.00941625	valid_1's l2: 0.0121879
# [2000]	training's l2: 0.00652373	valid_1's l2: 0.0100829
# [3000]	training's l2: 0.00504676	valid_1's l2: 0.00903009
# [4000]	training's l2: 0.00412658	valid_1's l2: 0.00846663
# [5000]	training's l2: 0.00345085	valid_1's l2: 0.00809506
# [6000]	training's l2: 0.00294655	valid_1's l2: 0.00782281
# [7000]	training's l2: 0.00255122	valid_1's l2: 0.00761003
# [8000]	training's l2: 0.00223521	valid_1's l2: 0.00747661
# [9000]	training's l2: 0.00197446	valid_1's l2: 0.00737175
# [10000]	training's l2: 0.00175365	valid_1's l2: 0.00730099
# [11000]	training's l2: 0.00156458	valid_1's l2: 0.00722846
# [12000]	training's l2: 0.00140393	valid_1's l2: 0.0071633
# [13000]	training's l2: 0.0012602	valid_1's l2: 0.00709962
# [14000]	training's l2: 0.0011378	valid_1's l2: 0.00706228
# Early stopping, best iteration is:
# [14249]	training's l2: 0.00110973	valid_1's l2: 0.00705458
# [('ts', 11609), ('B_HYC_DO', 11388), ('MCCS_NO3', 9937), ('B_HYC_MLSS', 9765), ('MCCS_NH4', 9732), ('B_QY_ORP', 9283), ('JS_CS_SW_ratio', 9156), ('B_CS_MQ_SSLL', 9050), ('B_HYC_JS_DO', 9006), ('minute', 8895), ('JS_LL', 8784), ('B_HYC_XD', 8665), ('JS_SW', 8622), ('HYC_DO_ratio', 8398), ('MCCS_NH4_NH3_ratio', 7774), ('CS_SW', 6406), ('JS_CS_LL_ratio', 6355), ('MCCS_NO3_NH3_ratio', 6061), ('CS_LL', 5775), ('CS_TN', 5442)]
# [1411.8167258243056, 1210.6841699667573]
# ************************************ 3 ************************************
# Training until validation scores don't improve for 200 rounds
# [1000]	training's l2: 0.00952025	valid_1's l2: 0.00955996
# [2000]	training's l2: 0.00658446	valid_1's l2: 0.00817186
# [3000]	training's l2: 0.00511337	valid_1's l2: 0.00750319
# [4000]	training's l2: 0.00415114	valid_1's l2: 0.00708078
# [5000]	training's l2: 0.00349208	valid_1's l2: 0.00679037
# [6000]	training's l2: 0.00299297	valid_1's l2: 0.00659359
# Early stopping, best iteration is:
# [6264]	training's l2: 0.00287796	valid_1's l2: 0.00652537
# [('ts', 5836), ('MCCS_NH4', 5387), ('MCCS_NO3', 4964), ('B_HYC_DO', 4931), ('B_QY_ORP', 4858), ('JS_CS_SW_ratio', 4210), ('B_HYC_MLSS', 3971), ('JS_SW', 3950), ('MCCS_NH4_NH3_ratio', 3658), ('minute', 3520), ('B_HYC_JS_DO', 3391), ('CS_SW', 3356), ('B_CS_MQ_SSLL', 3301), ('JS_LL', 3153), ('CS_COD', 2954), ('HYC_DO_ratio', 2911), ('B_HYC_XD', 2888), ('MCCS_NO3_NH3_ratio', 2872), ('CS_TN', 2768), ('JS_NH3', 2568)]
# [1411.8167258243056, 1210.6841699667573, 1320.726461313933]
# ************************************ 4 ************************************
# Training until validation scores don't improve for 200 rounds
# [1000]	training's l2: 0.00911055	valid_1's l2: 0.015468
# [2000]	training's l2: 0.00633967	valid_1's l2: 0.0136108
# [3000]	training's l2: 0.00489824	valid_1's l2: 0.0125362
# [4000]	training's l2: 0.00399526	valid_1's l2: 0.0119941
# [5000]	training's l2: 0.00334488	valid_1's l2: 0.0115185
# [6000]	training's l2: 0.00286594	valid_1's l2: 0.0112082
# [7000]	training's l2: 0.002488	valid_1's l2: 0.0110038
# [8000]	training's l2: 0.00218066	valid_1's l2: 0.0108312
# [9000]	training's l2: 0.00192398	valid_1's l2: 0.0106896
# [10000]	training's l2: 0.00171186	valid_1's l2: 0.0105869
# [11000]	training's l2: 0.00153018	valid_1's l2: 0.010492
# [12000]	training's l2: 0.00137233	valid_1's l2: 0.010413
# [13000]	training's l2: 0.00123144	valid_1's l2: 0.010372
# [14000]	training's l2: 0.00111506	valid_1's l2: 0.0103104
# Early stopping, best iteration is:
# [14455]	training's l2: 0.0010648	valid_1's l2: 0.0102866
# [('ts', 11938), ('B_HYC_DO', 11234), ('MCCS_NO3', 10215), ('B_HYC_MLSS', 9872), ('MCCS_NH4', 9715), ('B_QY_ORP', 9566), ('minute', 9418), ('B_HYC_JS_DO', 9351), ('JS_LL', 9250), ('JS_CS_SW_ratio', 9194), ('B_HYC_XD', 8977), ('B_CS_MQ_SSLL', 8886), ('HYC_DO_ratio', 8361), ('JS_SW', 8351), ('MCCS_NH4_NH3_ratio', 7749), ('JS_CS_LL_ratio', 6698), ('CS_SW', 6670), ('MCCS_NO3_NH3_ratio', 5999), ('CS_LL', 5957), ('CS_TN', 5502)]
# [1411.8167258243056, 1210.6841699667573, 1320.726461313933, 1322.0453204292792]
# ************************************ 5 ************************************
# Training until validation scores don't improve for 200 rounds
# [1000]	training's l2: 0.00935903	valid_1's l2: 0.0112862
# [2000]	training's l2: 0.00647964	valid_1's l2: 0.00969617
# [3000]	training's l2: 0.00501637	valid_1's l2: 0.00891422
# [4000]	training's l2: 0.00407584	valid_1's l2: 0.0084673
# [5000]	training's l2: 0.00341721	valid_1's l2: 0.00812499
# [6000]	training's l2: 0.00291809	valid_1's l2: 0.00787401
# [7000]	training's l2: 0.00252966	valid_1's l2: 0.00772694
# [8000]	training's l2: 0.00220383	valid_1's l2: 0.0076225
# Early stopping, best iteration is:
# [8428]	training's l2: 0.00208908	valid_1's l2: 0.00757739
# [('ts', 7597), ('B_HYC_DO', 6603), ('MCCS_NH4', 6504), ('MCCS_NO3', 6245), ('B_QY_ORP', 5983), ('JS_CS_SW_ratio', 5598), ('B_HYC_MLSS', 5588), ('JS_SW', 5243), ('minute', 5023), ('B_HYC_JS_DO', 4798), ('JS_LL', 4795), ('MCCS_NH4_NH3_ratio', 4741), ('B_CS_MQ_SSLL', 4587), ('HYC_DO_ratio', 4384), ('B_HYC_XD', 4354), ('CS_SW', 4170), ('MCCS_NO3_NH3_ratio', 3829), ('CS_COD', 3546), ('CS_TN', 3459), ('JS_NH3', 3347)]
# [1411.8167258243056, 1210.6841699667573, 1320.726461313933, 1322.0453204292792, 1358.191734875792]
# ************************************ 6 ************************************
# Training until validation scores don't improve for 200 rounds
# [1000]	training's l2: 0.00951663	valid_1's l2: 0.011935
# [2000]	training's l2: 0.00660892	valid_1's l2: 0.00960122
# [3000]	training's l2: 0.00513597	valid_1's l2: 0.00855365
# [4000]	training's l2: 0.00419539	valid_1's l2: 0.00796271
# [5000]	training's l2: 0.00352043	valid_1's l2: 0.00759289
# [6000]	training's l2: 0.00300861	valid_1's l2: 0.00726487
# [7000]	training's l2: 0.00260235	valid_1's l2: 0.00704854
# [8000]	training's l2: 0.00227581	valid_1's l2: 0.00688452
# [9000]	training's l2: 0.00200991	valid_1's l2: 0.00676173
# [10000]	training's l2: 0.00177989	valid_1's l2: 0.0066704
# [11000]	training's l2: 0.00158717	valid_1's l2: 0.00660342
# [12000]	training's l2: 0.00142292	valid_1's l2: 0.00655153
# [13000]	training's l2: 0.00127744	valid_1's l2: 0.0065142
# [14000]	training's l2: 0.00115192	valid_1's l2: 0.00646935
# Early stopping, best iteration is:
# [14352]	training's l2: 0.00111327	valid_1's l2: 0.00645333
# [('ts', 11939), ('B_HYC_DO', 11385), ('MCCS_NO3', 10228), ('MCCS_NH4', 9737), ('B_HYC_MLSS', 9593), ('B_QY_ORP', 9273), ('B_HYC_XD', 9168), ('B_HYC_JS_DO', 9122), ('minute', 9011), ('B_CS_MQ_SSLL', 8984), ('JS_CS_SW_ratio', 8840), ('JS_LL', 8789), ('JS_SW', 8531), ('HYC_DO_ratio', 8411), ('MCCS_NH4_NH3_ratio', 7634), ('JS_CS_LL_ratio', 6521), ('CS_SW', 6420), ('CS_LL', 6043), ('MCCS_NO3_NH3_ratio', 6022), ('CS_TN', 5520)]
# [1411.8167258243056, 1210.6841699667573, 1320.726461313933, 1322.0453204292792, 1358.191734875792, 1124.7786201051808]
# ************************************ 7 ************************************
# Training until validation scores don't improve for 200 rounds
# [1000]	training's l2: 0.00942777	valid_1's l2: 0.0104815
# [2000]	training's l2: 0.00648407	valid_1's l2: 0.00900098
# [3000]	training's l2: 0.00499712	valid_1's l2: 0.00826385
# [4000]	training's l2: 0.0040518	valid_1's l2: 0.00779734
# [5000]	training's l2: 0.0033934	valid_1's l2: 0.00747468
# [6000]	training's l2: 0.00290076	valid_1's l2: 0.00722522
# [7000]	training's l2: 0.00251642	valid_1's l2: 0.00706703
# [8000]	training's l2: 0.00220107	valid_1's l2: 0.00695866
# Early stopping, best iteration is:
# [8494]	training's l2: 0.00206697	valid_1's l2: 0.00692833
# [('ts', 7916), ('MCCS_NH4', 6594), ('B_HYC_DO', 6546), ('MCCS_NO3', 6457), ('B_QY_ORP', 6278), ('B_HYC_MLSS', 5624), ('JS_CS_SW_ratio', 5547), ('JS_SW', 5409), ('minute', 5081), ('B_HYC_JS_DO', 4862), ('MCCS_NH4_NH3_ratio', 4822), ('B_CS_MQ_SSLL', 4801), ('JS_LL', 4505), ('B_HYC_XD', 4414), ('HYC_DO_ratio', 4214), ('CS_SW', 4181), ('MCCS_NO3_NH3_ratio', 3906), ('CS_COD', 3696), ('CS_TN', 3683), ('JS_COD', 3317)]
# [1411.8167258243056, 1210.6841699667573, 1320.726461313933, 1322.0453204292792, 1358.191734875792, 1124.7786201051808, 1274.2476379078378]
# ************************************ 8 ************************************
# Training until validation scores don't improve for 200 rounds
# [1000]	training's l2: 0.00948296	valid_1's l2: 0.00991529
# [2000]	training's l2: 0.00652453	valid_1's l2: 0.00838118
# [3000]	training's l2: 0.00507014	valid_1's l2: 0.00761821
# [4000]	training's l2: 0.00412882	valid_1's l2: 0.00711888
# [5000]	training's l2: 0.00347143	valid_1's l2: 0.00678015
# [6000]	training's l2: 0.00297232	valid_1's l2: 0.00654416
# [7000]	training's l2: 0.00258223	valid_1's l2: 0.006425
# [8000]	training's l2: 0.00226633	valid_1's l2: 0.00627886
# [9000]	training's l2: 0.00200188	valid_1's l2: 0.00619396
# [10000]	training's l2: 0.00177575	valid_1's l2: 0.00612041
# [11000]	training's l2: 0.00158474	valid_1's l2: 0.00603974
# [12000]	training's l2: 0.00142033	valid_1's l2: 0.00599754
# Early stopping, best iteration is:
# [12412]	training's l2: 0.00135886	valid_1's l2: 0.00598153
# [('ts', 10594), ('B_HYC_DO', 9784), ('MCCS_NH4', 9018), ('MCCS_NO3', 8721), ('B_QY_ORP', 8437), ('B_HYC_MLSS', 8340), ('JS_CS_SW_ratio', 7928), ('minute', 7725), ('B_HYC_JS_DO', 7688), ('JS_LL', 7571), ('B_CS_MQ_SSLL', 7438), ('B_HYC_XD', 7251), ('JS_SW', 7226), ('HYC_DO_ratio', 7187), ('MCCS_NH4_NH3_ratio', 6822), ('CS_SW', 5762), ('MCCS_NO3_NH3_ratio', 5525), ('JS_CS_LL_ratio', 5062), ('CS_TN', 4854), ('CS_COD', 4825)]
# [1411.8167258243056, 1210.6841699667573, 1320.726461313933, 1322.0453204292792, 1358.191734875792, 1124.7786201051808, 1274.2476379078378, 1326.1878603056368]
# ************************************ 9 ************************************
# Training until validation scores don't improve for 200 rounds
# [1000]	training's l2: 0.00922049	valid_1's l2: 0.0151185
# [2000]	training's l2: 0.00644902	valid_1's l2: 0.0135027
# [3000]	training's l2: 0.0050222	valid_1's l2: 0.0128833
# [4000]	training's l2: 0.00410333	valid_1's l2: 0.0123181
# [5000]	training's l2: 0.00344486	valid_1's l2: 0.012102
# [6000]	training's l2: 0.00294525	valid_1's l2: 0.0118375
# [7000]	training's l2: 0.00255428	valid_1's l2: 0.0116568
# [8000]	training's l2: 0.00223204	valid_1's l2: 0.0115411
# [9000]	training's l2: 0.00196429	valid_1's l2: 0.0114444
# Early stopping, best iteration is:
# [9512]	training's l2: 0.00184952	valid_1's l2: 0.0113869
# [('ts', 8613), ('B_HYC_DO', 7539), ('MCCS_NH4', 7291), ('MCCS_NO3', 7275), ('B_QY_ORP', 6618), ('B_HYC_MLSS', 6321), ('JS_CS_SW_ratio', 6281), ('JS_SW', 6015), ('B_HYC_JS_DO', 5596), ('minute', 5533), ('JS_LL', 5380), ('MCCS_NH4_NH3_ratio', 5325), ('B_CS_MQ_SSLL', 5243), ('B_HYC_XD', 5191), ('HYC_DO_ratio', 5174), ('CS_SW', 4650), ('MCCS_NO3_NH3_ratio', 4360), ('CS_COD', 3888), ('CS_TN', 3825), ('JS_NH3', 3608)]
# [1411.8167258243056, 1210.6841699667573, 1320.726461313933, 1322.0453204292792, 1358.191734875792, 1124.7786201051808, 1274.2476379078378, 1326.1878603056368, 1459.5045765700831]
# ************************************ 10 ************************************
# Training until validation scores don't improve for 200 rounds
# [1000]	training's l2: 0.00932914	valid_1's l2: 0.0135905
# [2000]	training's l2: 0.00645555	valid_1's l2: 0.0122433
# [3000]	training's l2: 0.00502553	valid_1's l2: 0.0113871
# [4000]	training's l2: 0.00410508	valid_1's l2: 0.0108539
# [5000]	training's l2: 0.00343936	valid_1's l2: 0.010504
# [6000]	training's l2: 0.00294784	valid_1's l2: 0.0102858
# [7000]	training's l2: 0.00255929	valid_1's l2: 0.0100806
# [8000]	training's l2: 0.00224235	valid_1's l2: 0.00996513
# Early stopping, best iteration is:
# [7910]	training's l2: 0.00226903	valid_1's l2: 0.00994829
# [('ts', 7180), ('MCCS_NH4', 6367), ('B_HYC_DO', 6321), ('MCCS_NO3', 5976), ('B_QY_ORP', 5808), ('B_HYC_MLSS', 5136), ('JS_CS_SW_ratio', 4925), ('JS_SW', 4910), ('minute', 4748), ('B_HYC_JS_DO', 4472), ('MCCS_NH4_NH3_ratio', 4469), ('B_HYC_XD', 4346), ('B_CS_MQ_SSLL', 4246), ('JS_LL', 4239), ('HYC_DO_ratio', 4194), ('CS_SW', 3947), ('CS_COD', 3451), ('MCCS_NO3_NH3_ratio', 3429), ('CS_TN', 3376), ('JS_NH3', 3131)]
# [1411.8167258243056, 1210.6841699667573, 1320.726461313933, 1322.0453204292792, 1358.191734875792, 1124.7786201051808, 1274.2476379078378, 1326.1878603056368, 1459.5045765700831, 1391.6780720181553]
# s_scotrainre_list: [1411.8167258243056, 1210.6841699667573, 1320.726461313933, 1322.0453204292792, 1358.191734875792, 1124.7786201051808, 1274.2476379078378, 1326.1878603056368, 1459.5045765700831, 1391.6780720181553]
# s_score_mean: 1319.9861179316963
# s_score_std: 93.10521355799897
# ************************************ 1 ************************************
# Training until validation scores don't improve for 200 rounds
# [1000]	training's l2: 0.00799562	valid_1's l2: 0.0159857
# [2000]	training's l2: 0.00577314	valid_1's l2: 0.0149325
# [3000]	training's l2: 0.0045504	valid_1's l2: 0.0143762
# [4000]	training's l2: 0.00374531	valid_1's l2: 0.0139926
# [5000]	training's l2: 0.00317338	valid_1's l2: 0.0136947
# [6000]	training's l2: 0.00273117	valid_1's l2: 0.0134865
# [7000]	training's l2: 0.00237772	valid_1's l2: 0.0133522
# [8000]	training's l2: 0.00208745	valid_1's l2: 0.0132503
# [9000]	training's l2: 0.00184397	valid_1's l2: 0.0131548
# [10000]	training's l2: 0.00164413	valid_1's l2: 0.013052
# [11000]	training's l2: 0.00146886	valid_1's l2: 0.0129647
# Early stopping, best iteration is:
# [11363]	training's l2: 0.0014113	valid_1's l2: 0.0129553
# [('N_HYC_DO', 9432), ('ts', 8759), ('N_QY_ORP', 8398), ('MCCS_NO3', 8334), ('N_HYC_NH4', 8311), ('MCCS_NH4', 7884), ('HYC_DO_ratio', 7226), ('N_HYC_MLSS', 7052), ('N_HYC_XD', 6963), ('JS_CS_SW_ratio', 6753), ('JS_SW', 6627), ('JS_LL', 6554), ('minute', 6446), ('N_CS_MQ_SSLL', 5860), ('N_HYC_JS_DO', 5775), ('MCCS_NH4_NH3_ratio', 5736), ('CS_SW', 5005), ('JS_CS_LL_ratio', 4820), ('MCCS_NO3_NH3_ratio', 4675), ('CS_TN', 4311)]
# [1186.3737118641652]
# ************************************ 2 ************************************
# Training until validation scores don't improve for 200 rounds
# [1000]	training's l2: 0.00824449	valid_1's l2: 0.0114034
# [2000]	training's l2: 0.00585493	valid_1's l2: 0.00995795
# [3000]	training's l2: 0.0045881	valid_1's l2: 0.00922533
# [4000]	training's l2: 0.00375853	valid_1's l2: 0.00877444
# [5000]	training's l2: 0.0031798	valid_1's l2: 0.00849402
# [6000]	training's l2: 0.00273424	valid_1's l2: 0.00830951
# [7000]	training's l2: 0.00238508	valid_1's l2: 0.00816686
# [8000]	training's l2: 0.0020943	valid_1's l2: 0.00805677
# [9000]	training's l2: 0.00185455	valid_1's l2: 0.00796413
# [10000]	training's l2: 0.00165114	valid_1's l2: 0.00790071
# [11000]	training's l2: 0.00147843	valid_1's l2: 0.00784943
# [12000]	training's l2: 0.00132996	valid_1's l2: 0.00779542
# [13000]	training's l2: 0.00119827	valid_1's l2: 0.00776159
# [14000]	training's l2: 0.00108131	valid_1's l2: 0.00773314
# [15000]	training's l2: 0.000979476	valid_1's l2: 0.00770959
# Early stopping, best iteration is:
# [15417]	training's l2: 0.000940849	valid_1's l2: 0.00770278
# [('N_HYC_DO', 12563), ('ts', 11414), ('N_HYC_NH4', 10934), ('MCCS_NO3', 10627), ('N_QY_ORP', 10588), ('N_HYC_XD', 10350), ('N_HYC_MLSS', 10319), ('HYC_DO_ratio', 10123), ('MCCS_NH4', 9543), ('JS_LL', 9317), ('N_CS_MQ_SSLL', 9123), ('minute', 9082), ('JS_CS_SW_ratio', 8968), ('N_HYC_JS_DO', 8675), ('JS_SW', 8666), ('JS_CS_LL_ratio', 7354), ('MCCS_NH4_NH3_ratio', 7195), ('CS_SW', 6601), ('CS_LL', 6255), ('MCCS_NO3_NH3_ratio', 6014)]
# [1186.3737118641652, 1040.9949407413853]
# ************************************ 3 ************************************
# Training until validation scores don't improve for 200 rounds
# [1000]	training's l2: 0.00835677	valid_1's l2: 0.00895984
# [2000]	training's l2: 0.00594748	valid_1's l2: 0.0078112
# [3000]	training's l2: 0.00464919	valid_1's l2: 0.00720213
# [4000]	training's l2: 0.00380757	valid_1's l2: 0.00685274
# [5000]	training's l2: 0.00321574	valid_1's l2: 0.00659071
# [6000]	training's l2: 0.00276388	valid_1's l2: 0.00640175
# [7000]	training's l2: 0.00240645	valid_1's l2: 0.00629344
# [8000]	training's l2: 0.00211057	valid_1's l2: 0.00620091
# [9000]	training's l2: 0.00186668	valid_1's l2: 0.00612144
# Early stopping, best iteration is:
# [9484]	training's l2: 0.00176261	valid_1's l2: 0.00609635
# [('N_HYC_DO', 7913), ('ts', 7760), ('N_QY_ORP', 7403), ('MCCS_NO3', 7174), ('N_HYC_NH4', 6878), ('MCCS_NH4', 6628), ('HYC_DO_ratio', 6067), ('N_HYC_MLSS', 5896), ('N_HYC_XD', 5731), ('JS_SW', 5715), ('JS_CS_SW_ratio', 5450), ('minute', 5398), ('JS_LL', 5124), ('MCCS_NH4_NH3_ratio', 4623), ('N_CS_MQ_SSLL', 4533), ('N_HYC_JS_DO', 4487), ('CS_SW', 4417), ('MCCS_NO3_NH3_ratio', 3966), ('CS_COD', 3810), ('JS_CS_LL_ratio', 3718)]
# [1186.3737118641652, 1040.9949407413853, 1063.753598698717]
# ************************************ 4 ************************************
# Training until validation scores don't improve for 200 rounds
# [1000]	training's l2: 0.00803361	valid_1's l2: 0.0144219
# [2000]	training's l2: 0.00571947	valid_1's l2: 0.0128259
# [3000]	training's l2: 0.00447904	valid_1's l2: 0.0120976
# [4000]	training's l2: 0.00366543	valid_1's l2: 0.0116714
# [5000]	training's l2: 0.0030906	valid_1's l2: 0.011412
# [6000]	training's l2: 0.00266245	valid_1's l2: 0.0111871
# [7000]	training's l2: 0.00231149	valid_1's l2: 0.011041
# [8000]	training's l2: 0.00204019	valid_1's l2: 0.0109609
# [9000]	training's l2: 0.00180213	valid_1's l2: 0.0108748
# [10000]	training's l2: 0.00160491	valid_1's l2: 0.0108054
# [11000]	training's l2: 0.00143658	valid_1's l2: 0.0107428
# [12000]	training's l2: 0.00129094	valid_1's l2: 0.0107009
# Early stopping, best iteration is:
# [12273]	training's l2: 0.00125382	valid_1's l2: 0.0106855
# [('N_HYC_DO', 9945), ('ts', 9763), ('N_HYC_NH4', 9137), ('N_QY_ORP', 9069), ('MCCS_NO3', 8991), ('MCCS_NH4', 7830), ('N_HYC_MLSS', 7733), ('HYC_DO_ratio', 7709), ('N_HYC_XD', 7656), ('minute', 7344), ('JS_CS_SW_ratio', 7335), ('JS_SW', 7124), ('JS_LL', 7054), ('N_CS_MQ_SSLL', 6638), ('N_HYC_JS_DO', 6329), ('MCCS_NH4_NH3_ratio', 6025), ('JS_CS_LL_ratio', 5333), ('CS_SW', 5317), ('MCCS_NO3_NH3_ratio', 4987), ('CS_TN', 4631)]
# [1186.3737118641652, 1040.9949407413853, 1063.753598698717, 1133.2320806366536]
# ************************************ 5 ************************************
# Training until validation scores don't improve for 200 rounds
# [1000]	training's l2: 0.00824696	valid_1's l2: 0.0100777
# [2000]	training's l2: 0.00588098	valid_1's l2: 0.00887325
# [3000]	training's l2: 0.00459305	valid_1's l2: 0.00827121
# [4000]	training's l2: 0.00377058	valid_1's l2: 0.00785576
# [5000]	training's l2: 0.00317937	valid_1's l2: 0.0075707
# [6000]	training's l2: 0.00273712	valid_1's l2: 0.00739155
# [7000]	training's l2: 0.00238431	valid_1's l2: 0.0072634
# [8000]	training's l2: 0.0020965	valid_1's l2: 0.00714197
# [9000]	training's l2: 0.00185266	valid_1's l2: 0.0070394
# [10000]	training's l2: 0.00164909	valid_1's l2: 0.0069725
# [11000]	training's l2: 0.00147751	valid_1's l2: 0.00692485
# [12000]	training's l2: 0.001324	valid_1's l2: 0.00689585
# [13000]	training's l2: 0.00119024	valid_1's l2: 0.0068502
# [14000]	training's l2: 0.00107378	valid_1's l2: 0.00681433
# Early stopping, best iteration is:
# [14574]	training's l2: 0.00101252	valid_1's l2: 0.00679221
# [('N_HYC_DO', 11677), ('ts', 10901), ('N_HYC_NH4', 10625), ('N_QY_ORP', 10320), ('MCCS_NO3', 10112), ('HYC_DO_ratio', 9961), ('N_HYC_MLSS', 9382), ('N_HYC_XD', 9289), ('MCCS_NH4', 9185), ('JS_LL', 8789), ('minute', 8789), ('JS_CS_SW_ratio', 8553), ('N_CS_MQ_SSLL', 8334), ('JS_SW', 8155), ('N_HYC_JS_DO', 8155), ('JS_CS_LL_ratio', 6972), ('MCCS_NH4_NH3_ratio', 6849), ('CS_SW', 6172), ('MCCS_NO3_NH3_ratio', 5838), ('CS_LL', 5800)]
# [1186.3737118641652, 1040.9949407413853, 1063.753598698717, 1133.2320806366536, 1047.0754732801888]
# ************************************ 6 ************************************
# Training until validation scores don't improve for 200 rounds
# [1000]	training's l2: 0.00832798	valid_1's l2: 0.0106503
# [2000]	training's l2: 0.00593485	valid_1's l2: 0.00902917
# [3000]	training's l2: 0.00463829	valid_1's l2: 0.00821341
# [4000]	training's l2: 0.0038186	valid_1's l2: 0.00782487
# [5000]	training's l2: 0.00322367	valid_1's l2: 0.00751117
# [6000]	training's l2: 0.00277619	valid_1's l2: 0.00729106
# [7000]	training's l2: 0.00240825	valid_1's l2: 0.00716252
# [8000]	training's l2: 0.00211569	valid_1's l2: 0.00706981
# [9000]	training's l2: 0.00187576	valid_1's l2: 0.00696358
# [10000]	training's l2: 0.00167208	valid_1's l2: 0.00689886
# [11000]	training's l2: 0.00149454	valid_1's l2: 0.00684772
# [12000]	training's l2: 0.00134159	valid_1's l2: 0.00678713
# Early stopping, best iteration is:
# [11908]	training's l2: 0.00135442	valid_1's l2: 0.00678492
# [('N_HYC_DO', 9926), ('ts', 9441), ('MCCS_NO3', 8771), ('N_QY_ORP', 8457), ('N_HYC_NH4', 8450), ('MCCS_NH4', 7957), ('N_HYC_MLSS', 7801), ('HYC_DO_ratio', 7626), ('N_HYC_XD', 7111), ('JS_CS_SW_ratio', 7027), ('minute', 6946), ('JS_LL', 6926), ('JS_SW', 6824), ('N_HYC_JS_DO', 6358), ('N_CS_MQ_SSLL', 6246), ('MCCS_NH4_NH3_ratio', 5541), ('CS_SW', 5344), ('JS_CS_LL_ratio', 5063), ('MCCS_NO3_NH3_ratio', 4932), ('CS_TN', 4530)]
# [1186.3737118641652, 1040.9949407413853, 1063.753598698717, 1133.2320806366536, 1047.0754732801888, 964.0340259239937]
# ************************************ 7 ************************************
# Training until validation scores don't improve for 200 rounds
# [1000]	training's l2: 0.00827353	valid_1's l2: 0.00907926
# [2000]	training's l2: 0.00584387	valid_1's l2: 0.00794914
# [3000]	training's l2: 0.00455852	valid_1's l2: 0.00735253
# [4000]	training's l2: 0.00374175	valid_1's l2: 0.00694374
# [5000]	training's l2: 0.00315456	valid_1's l2: 0.00667005
# [6000]	training's l2: 0.00270418	valid_1's l2: 0.00649006
# [7000]	training's l2: 0.0023542	valid_1's l2: 0.00636169
# [8000]	training's l2: 0.00206763	valid_1's l2: 0.00627687
# [9000]	training's l2: 0.00183112	valid_1's l2: 0.00620812
# [10000]	training's l2: 0.00163076	valid_1's l2: 0.00614909
# [11000]	training's l2: 0.0014578	valid_1's l2: 0.00609304
# [12000]	training's l2: 0.00130876	valid_1's l2: 0.0060618
# [13000]	training's l2: 0.00118149	valid_1's l2: 0.00604361
# [14000]	training's l2: 0.00106612	valid_1's l2: 0.00601685
# Early stopping, best iteration is:
# [14597]	training's l2: 0.00100355	valid_1's l2: 0.00599627
# [('N_HYC_DO', 12116), ('ts', 10915), ('N_HYC_NH4', 10676), ('N_QY_ORP', 10380), ('MCCS_NO3', 10177), ('HYC_DO_ratio', 9585), ('N_HYC_MLSS', 9355), ('N_HYC_XD', 9228), ('MCCS_NH4', 9190), ('minute', 8830), ('JS_LL', 8650), ('JS_CS_SW_ratio', 8553), ('N_CS_MQ_SSLL', 8474), ('JS_SW', 8197), ('N_HYC_JS_DO', 7825), ('JS_CS_LL_ratio', 6894), ('MCCS_NH4_NH3_ratio', 6875), ('CS_SW', 6121), ('CS_LL', 5904), ('MCCS_NO3_NH3_ratio', 5641)]
# [1186.3737118641652, 1040.9949407413853, 1063.753598698717, 1133.2320806366536, 1047.0754732801888, 964.0340259239937, 935.7981173818991]
# ************************************ 8 ************************************
# Training until validation scores don't improve for 200 rounds
# [1000]	training's l2: 0.00828535	valid_1's l2: 0.00940156
# [2000]	training's l2: 0.00588256	valid_1's l2: 0.00849038
# [3000]	training's l2: 0.00460433	valid_1's l2: 0.00791365
# [4000]	training's l2: 0.00379536	valid_1's l2: 0.00754687
# [5000]	training's l2: 0.00320552	valid_1's l2: 0.00725846
# [6000]	training's l2: 0.0027629	valid_1's l2: 0.00710104
# [7000]	training's l2: 0.00240915	valid_1's l2: 0.0069521
# Early stopping, best iteration is:
# [6880]	training's l2: 0.00244937	valid_1's l2: 0.00694003
# [('N_HYC_DO', 5972), ('ts', 5880), ('N_QY_ORP', 5560), ('MCCS_NO3', 5322), ('MCCS_NH4', 5078), ('N_HYC_NH4', 5033), ('JS_SW', 4351), ('N_HYC_MLSS', 4129), ('HYC_DO_ratio', 4023), ('JS_CS_SW_ratio', 4020), ('N_HYC_XD', 3999), ('minute', 3711), ('MCCS_NH4_NH3_ratio', 3593), ('JS_LL', 3585), ('CS_SW', 3188), ('MCCS_NO3_NH3_ratio', 3120), ('CS_COD', 3091), ('CS_TN', 2987), ('N_CS_MQ_SSLL', 2774), ('N_HYC_JS_DO', 2758)]
# [1186.3737118641652, 1040.9949407413853, 1063.753598698717, 1133.2320806366536, 1047.0754732801888, 964.0340259239937, 935.7981173818991, 1135.1377074971713]
# ************************************ 9 ************************************
# Training until validation scores don't improve for 200 rounds
# [1000]	training's l2: 0.00808562	valid_1's l2: 0.0147729
# [2000]	training's l2: 0.00582807	valid_1's l2: 0.0139793
# [3000]	training's l2: 0.00457323	valid_1's l2: 0.0135936
# [4000]	training's l2: 0.00377086	valid_1's l2: 0.0132647
# [5000]	training's l2: 0.00319098	valid_1's l2: 0.0130013
# [6000]	training's l2: 0.00276379	valid_1's l2: 0.0128451
# [7000]	training's l2: 0.00240897	valid_1's l2: 0.0127335
# Early stopping, best iteration is:
# [7188]	training's l2: 0.00234961	valid_1's l2: 0.0127033
# [('ts', 6131), ('N_HYC_DO', 6001), ('N_QY_ORP', 5712), ('MCCS_NO3', 5659), ('N_HYC_NH4', 5310), ('MCCS_NH4', 5080), ('HYC_DO_ratio', 4571), ('JS_SW', 4384), ('JS_CS_SW_ratio', 4318), ('N_HYC_MLSS', 4294), ('N_HYC_XD', 4172), ('JS_LL', 3956), ('minute', 3669), ('MCCS_NH4_NH3_ratio', 3537), ('CS_SW', 3478), ('CS_COD', 3186), ('N_HYC_JS_DO', 3186), ('MCCS_NO3_NH3_ratio', 3026), ('CS_TN', 3014), ('N_CS_MQ_SSLL', 2824)]
# [1186.3737118641652, 1040.9949407413853, 1063.753598698717, 1133.2320806366536, 1047.0754732801888, 964.0340259239937, 935.7981173818991, 1135.1377074971713, 1221.999681089402]
# ************************************ 10 ************************************
# Training until validation scores don't improve for 200 rounds
# [1000]	training's l2: 0.008274	valid_1's l2: 0.0113023
# [2000]	training's l2: 0.00586702	valid_1's l2: 0.0099719
# [3000]	training's l2: 0.00461204	valid_1's l2: 0.0093107
# [4000]	training's l2: 0.00378783	valid_1's l2: 0.00894517
# [5000]	training's l2: 0.00319168	valid_1's l2: 0.00866346
# [6000]	training's l2: 0.00273863	valid_1's l2: 0.00847685
# [7000]	training's l2: 0.00238552	valid_1's l2: 0.00834705
# [8000]	training's l2: 0.00209284	valid_1's l2: 0.00827008
# [9000]	training's l2: 0.00185522	valid_1's l2: 0.0081776
# [10000]	training's l2: 0.00164999	valid_1's l2: 0.00810991
# Early stopping, best iteration is:
# [10362]	training's l2: 0.00158394	valid_1's l2: 0.00809078
# [('N_HYC_DO', 8737), ('ts', 8420), ('MCCS_NO3', 7755), ('N_QY_ORP', 7681), ('N_HYC_NH4', 7467), ('MCCS_NH4', 6929), ('HYC_DO_ratio', 6874), ('N_HYC_MLSS', 6676), ('N_HYC_XD', 6292), ('JS_CS_SW_ratio', 6187), ('JS_SW', 6112), ('minute', 6059), ('JS_LL', 5620), ('N_HYC_JS_DO', 5141), ('N_CS_MQ_SSLL', 5138), ('MCCS_NH4_NH3_ratio', 5111), ('CS_SW', 4525), ('MCCS_NO3_NH3_ratio', 4246), ('CS_COD', 4130), ('CS_TN', 4052)]
# [1186.3737118641652, 1040.9949407413853, 1063.753598698717, 1133.2320806366536, 1047.0754732801888, 964.0340259239937, 935.7981173818991, 1135.1377074971713, 1221.999681089402, 1098.799272108841]
# s_scotrainre_list: [1186.3737118641652, 1040.9949407413853, 1063.753598698717, 1133.2320806366536, 1047.0754732801888, 964.0340259239937, 935.7981173818991, 1135.1377074971713, 1221.999681089402, 1098.799272108841]
# s_score_mean: 1082.7198609222419
# s_score_std: 86.45472118768149

# %%
# 特征重要性
Feass0.groupby(['feas'])['sorce'].mean().sort_values(ascending=False).reset_index(),\
Feass1.groupby(['feas'])['sorce'].mean().sort_values(ascending=False).reset_index()
# Out:
# (                  feas   sorce
#  0                   ts  9268.0
#  1             B_HYC_DO  8455.5
#  2             MCCS_NH4  7842.1
#  3             MCCS_NO3  7793.7
#  4             B_QY_ORP  7342.5
#  5           B_HYC_MLSS  7160.1
#  6       JS_CS_SW_ratio  6882.8
#  7               minute  6558.0
#  8                JS_SW  6487.2
#  9          B_HYC_JS_DO  6465.0
#  10               JS_LL  6319.4
#  11        B_CS_MQ_SSLL  6299.7
#  12            B_HYC_XD  6150.7
#  13        HYC_DO_ratio  5922.6
#  14  MCCS_NH4_NH3_ratio  5914.4
#  15               CS_SW  5094.7
#  16  MCCS_NO3_NH3_ratio  4695.4
#  17      JS_CS_LL_ratio  4311.0
#  18               CS_TN  4288.5
#  19              CS_COD  4263.4
#  20              JS_NH3  3981.2
#  21              JS_COD  3952.6
#  22               CS_LL  3939.5
#  23      JS_CS_TN_ratio  3721.0
#  24               JS_TN  3409.0
#  25     JS_CS_COD_ratio  3404.2
#  26      CS_MQ_LL_ratio  3183.0
#  27     JS_CS_NH3_ratio  2665.0
#  28              CS_NH3  2441.9
#  29           B_HYC_NH4  2400.4,
#                    feas   sorce
#  0             N_HYC_DO  9428.2
#  1                   ts  8938.4
#  2             N_QY_ORP  8356.8
#  3             MCCS_NO3  8292.2
#  4            N_HYC_NH4  8282.1
#  5             MCCS_NH4  7530.4
#  6         HYC_DO_ratio  7376.5
#  7           N_HYC_MLSS  7263.7
#  8             N_HYC_XD  7079.1
#  9       JS_CS_SW_ratio  6716.4
#  10              minute  6627.4
#  11               JS_SW  6615.5
#  12               JS_LL  6557.5
#  13        N_CS_MQ_SSLL  5994.4
#  14         N_HYC_JS_DO  5868.9
#  15  MCCS_NH4_NH3_ratio  5508.5
#  16               CS_SW  5016.8
#  17      JS_CS_LL_ratio  4859.6
#  18  MCCS_NO3_NH3_ratio  4644.5
#  19               CS_TN  4399.3
#  20              CS_COD  4347.7
#  21               CS_LL  4150.5
#  22              JS_NH3  4042.2
#  23      JS_CS_TN_ratio  3780.5
#  24      CS_MQ_LL_ratio  3746.0
#  25               JS_TN  3689.0
#  26              JS_COD  3682.1
#  27     JS_CS_COD_ratio  3426.1
#  28     JS_CS_NH3_ratio  2609.5
#  29              CS_NH3  2239.2)

# %%
# 线下得分
1/(1+(scores0+scores1)/2)*1000
# Out:
# 0.8317025106550375

# %%
sub = pd.read_csv('sample_submission.csv')
sub['Label1'] = np.expm1(lgb_test0)
sub['Label2'] = np.expm1(lgb_test1)
sub.to_csv('1.csv', index=False)
